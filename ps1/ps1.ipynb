# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
path = "./data/ds3_valid.csv"
data = pd.read_csv(path)

# %%
data.describe()
# Out:
#                 t         x_1         x_2           y
# count  124.000000  124.000000  124.000000  124.000000
# mean     0.500000   -0.238477    0.074420    0.096774
# std      0.502028    2.138705    2.232863    0.296849
# min      0.000000   -5.280389   -4.438808    0.000000
# 25%      0.000000   -1.955857   -1.524093    0.000000
# 50%      0.500000    0.803983    0.122778    0.000000
# 75%      1.000000    1.540350    1.832902    0.000000
# max      1.000000    2.466355    4.719832    1.000000

# %%
data.plot(kind='scatter', x="x_1", y="x_2", c="y", cmap=plt.get_cmap("jet"))
# Out:
# <AxesSubplot:xlabel='x_1', ylabel='x_2'>

# %%
y = np.array([[0.6], [0.2], [0.4], [0.8], [0.9]])

# %%
z = y[y > 0.5]
print(sum(y>0.5))
# Out:
# [3]
